# %%
import os
import pandas as pd

# %% [markdown]
# #### 2.1. Load Dataset from Local Storage
#
# We read the previously saved Parquet file into a Pandas DataFrame.
# Using Parquet ensures fast loading and preserves data types.

# %%
df = pd.read_parquet("./data/1/df.parquet")

# %% [markdown]
# #### 2.2. Initial Data Exploration
#
# We display the first 5 rows to get a quick overview of the dataset's structure
# and verify that the data loaded correctly.

# %%
print("First 5 rows of the dataset:")
display(df.head())
# Out:
# First 5 rows of the dataset:
#    step      type     amount       nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   371  CASH_OUT  367336.05  sdv-pii-r8zd6     4514816.83      2108392.86
# 1   368  TRANSFER     238.63  sdv-pii-xq6z3      430944.71       1865444.6
# 2   141  CASH_OUT     254.93  sdv-pii-805w0      839593.53      8008353.88
# 3   191   CASH_IN  501547.39  sdv-pii-279tw        41226.4        28633.52
# 4   169  TRANSFER    71832.0  sdv-pii-ksz58       248694.6       793617.86
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  sdv-pii-q6998      1265486.06      2454140.46        0               0
# 1  sdv-pii-n2ql8       107927.46         2021.16        0               0
# 2  sdv-pii-yo0z6       773352.22           20.79        0               0
# 3  sdv-pii-9zlyl      6825363.55     16442078.24        0               0
# 4  sdv-pii-0ykbo       579313.76       829850.96        0               0

# %% [markdown]
# We also print the dataset's shape to understand the number of rows (transactions)
# and columns (features).

# %%
print(f"Dataset shape: {df.shape[0]} rows x {df.shape[1]} columns")
# Out:
# Dataset shape: 21000000 rows x 11 columns

# %% [markdown]
# #### 2.3. Column Data Types
#
# Displaying the data type of each column helps identify:
# - Numerical features (Int64, Float64) suitable for calculations
# - Categorical features (string) suitable for encoding or analysis
# - Target variable(s) for fraud detection: 'isFraud'

# %%
print("Column data types:")
display(df.dtypes.to_frame("Data Type"))
# Out:
# Column data types:
#                      Data Type
# step                     Int64
# type            string[python]
# amount                 Float64
# nameOrig        string[python]
# oldbalanceOrg          Float64
# newbalanceOrig         Float64
# nameDest        string[python]
# oldbalanceDest         Float64
# newbalanceDest         Float64
# isFraud                  Int64
# isFlaggedFraud           Int64

# %% [markdown]
# #### 2.4. Descriptive Statistics
#
# We calculate summary statistics for all columns to understand:
# - The distribution of numerical features (mean, min, max, std)
# - The unique values and counts for categorical features
# - Potential anomalies or unexpected ranges in the data

# %%
print("Descriptive statistics for all columns:")
display(df.describe(include="all").T)
# Out:
# Descriptive statistics for all columns:
#                      count    unique          top     freq            mean  \
# step            21000000.0      <NA>         <NA>     <NA>      238.869977
# type              21000000         5     CASH_OUT  7392758             NaN
# amount          21000000.0      <NA>         <NA>     <NA>    179899.52086
# nameOrig          21000000  11464100  C1727902553       14             NaN
# oldbalanceOrg   21000000.0      <NA>         <NA>     <NA>  1337090.191497
# newbalanceOrig  21000000.0      <NA>         <NA>     <NA>  2089204.302756
# nameDest          21000000   8219031   C985934102      292             NaN
# oldbalanceDest  21000000.0      <NA>         <NA>     <NA>  1939226.612396
# newbalanceDest  21000000.0      <NA>         <NA>     <NA>  3756326.413547
# isFraud         21000000.0      <NA>         <NA>     <NA>        0.001308
# isFlaggedFraud  21000000.0      <NA>         <NA>     <NA>        0.000003
#
#                             std   min          25%          50%           75%  \
# step                 163.244711   1.0        112.0        205.0         333.0
# type                        NaN   NaN          NaN          NaN           NaN
# amount            253462.841157   0.0   18588.0975    82421.835   238472.9125
# nameOrig                    NaN   NaN          NaN          NaN           NaN
# oldbalanceOrg    2576687.424684  0.01     10633.18   215652.925  1419982.4125
# newbalanceOrig   3416911.618226   0.0   58884.7675   586785.795    2605437.03
# nameDest                    NaN   NaN          NaN          NaN           NaN
# oldbalanceDest    2508570.53668  0.01  273171.8275  1012997.705  2634455.3575
# newbalanceDest  10367144.491859   0.0       101.26    64790.495  2020361.3425
# isFraud                0.036144   0.0          0.0          0.0           0.0
# isFlaggedFraud          0.00169   0.0          0.0          0.0           0.0
#
#                          max
# step                   743.0
# type                     NaN
# amount            6007851.17
# nameOrig                 NaN
# oldbalanceOrg    40283517.67
# newbalanceOrig   38668109.84
# nameDest                 NaN
# oldbalanceDest   44522776.72
# newbalanceDest  271284551.63
# isFraud                  1.0
# isFlaggedFraud           1.0

# %% [markdown]
# #### 2.5. Missing Values Check
#
# We check for missing values to ensure data completeness.
# A total of 0 missing values means the dataset is complete and no imputation is needed.

# %%
missing_count = df.isna().sum().sum()
print(f"Total missing values in the dataset: {missing_count}")
# Out:
# Total missing values in the dataset: 0

# %% [markdown]
# #### 2.6. Duplicated Rows Check
#
# We check for duplicate rows which could bias analysis or model training.
# A total of 0 duplicates means the dataset has unique transactions.

# %%
duplicate_count = df.duplicated().sum()
print(f"Total duplicated rows in the dataset: {duplicate_count}")
# Out:
# Total duplicated rows in the dataset: 0

# %% [markdown]
# #### 2.7. Save Cleaned Dataset
#
# After validation, we save the cleaned dataset to a new folder.
# This allows us to preserve a verified copy for future analysis or model training.

# %%
os.makedirs("./data/2/", exist_ok=True)
df.to_parquet("./data/2/df.parquet", index=False)
